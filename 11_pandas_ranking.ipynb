# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(range(4),index=['d','a','b','c'])

# %%
s
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
s['d']
# Out:
# 0

# %%
s.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
data=pd.read_csv('GlobalFirePower.csv')
data.head(5)
# Out:
#          Country ISO3  Rank  Total Population  Manpower Available  \
# 0  United States  USA     1         323995528           145215000
# 1         Russia  RUS     2         142355415            70000000
# 2          China  CHN     3        1373541278           750000000
# 3          India  IND     4        1266883598           616000000
# 4         France  FRA     5          66836154            30000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 0        120025000                4220000                   2363675
# 1         47000000                1355000                   3371027
# 2        619000000               19550000                   3712500
# 3        489600000               22900000                   4207250
# 4         23750000                 775000                    387635
#
#    Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 0           1373650             990025  ...                 224792
# 1            798527            2572500  ...                  87157
# 2           2260000            1452500  ...                  86000
# 3           1362500            2844750  ...                  63974
# 4            204000             183635  ...                  29640
#
#    Serivecable Airports  Defense Budget  External Debt  \
# 0                 13513          587800       17910000
# 1                  1218           44600         514800
# 2                   507          161700         983500
# 3                   346           51000         507000
# 4                   464           35000        5360000
#
#    Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 0                   117600                 18560000                9826675
# 1                   365500                  3745000               17098242
# 2                  3092000                 21270000                9596961
# 3                   359100                  8721000                3287263
# 4                   138200                  2737000                 643801
#
#    Coastline (km)  Shared Borders (km)  Waterways (km)
# 0           19924                12048           41009
# 1           37653                22408          102000
# 2           14500                22457          110000
# 3            7000                13888           14500
# 4            4853                 4072            8501
#
# [5 rows x 47 columns]

# %%
x=data.sort_index(axis=1)

# %%
x.head(4)
# Out:
#    Active Personnel  Aircraft Carriers  Armored Fighting Vehicles  \
# 0           1373650                 19                      41062
# 1            798527                  1                      31298
# 2           2260000                  1                       4788
# 3           1362500                  3                       6704
#
#    Attack Aircraft  Attack Helicopters Coastline (km)  Combat Tanks  \
# 0             2785                 947          19924          5884
# 1             1438                 490          37653         20216
# 2             1385                 206          14500          6457
# 3              809                  16           7000          4426
#
#    Consumption (bbl/dy)  Corvettes        Country  ...  Submarines  \
# 0              19000000          0  United States  ...          70
# 1               3320000         81         Russia  ...          63
# 2              10120000         35          China  ...          68
# 3               3510000         23          India  ...          15
#
#    Total Aircraft Strength  Total Helicopter Strength  \
# 0                    13762                       6065
# 1                     3794                       1389
# 2                     2955                        912
# 3                     2102                        666
#
#    Total Military Personnel  Total Naval Assets  Total Population  \
# 0                   2363675                 415         323995528
# 1                   3371027                 352         142355415
# 2                   3712500                 714        1373541278
# 3                   4207250                 295        1266883598
#
#    Towed Artillery Trainer Aircraft  Transport Aircraft  Waterways (km)
# 0             1299             2831                5739           41009
# 1             4625              387                1124          102000
# 2             6246              352                 782          110000
# 3             7414              323                 857           14500
#
# [4 rows x 47 columns]

# %%
x=data.sort_index(axis=1,ascending=False)

# %%
x=data.sort_values(by="ISO3")

# %%
x.head(4)
# Out:
#         Country ISO3  Rank  Total Population  Manpower Available  \
# 68  Afghanistan  AFG    69          33332025            14000000
# 89      Albania  ALB    90           3038594             1515000
# 24      Algeria  ALG    25          40263711            20400000
# 50       Angola  ANG    51          20172332             6030000
#
#     Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 68          8000000                 765000                    200000
# 89          1300000                  62000                     64000
# 24         17250000                 675000                    792350
# 50          3040000                 310000                    175500
#
#     Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 68            200000                  0  ...                      0
# 89             50000              14000  ...                    339
# 24            520000             272350  ...                   3973
# 50            107000              68500  ...                   2764
#
#     Serivecable Airports  Defense Budget  External Debt  \
# 68                    43           11500           1280
# 89                     4             110           7797
# 24                   157           10570           5934
# 50                   176            4150          37700
#
#     Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 68                    66810                    64080                 652230
# 89                     3213                    34210                  28748
# 24                   115000                   609400                2381741
# 50                    20430                   187300                1246700
#
#     Coastline (km)  Shared Borders (km)    Waterways (km)
# 68      Landlocked                 5987              1200
# 89             362                  691                41
# 24             998                 6734  Minimum not met.
# 50            1600                 5369              1300
#
# [4 rows x 47 columns]

# %%
x=data.sort_values(by="Rank",ascending=False)

# %%
x.head(4)
# Out:
#           Country ISO3  Rank  Total Population  Manpower Available  \
# 132        Bhutan  BUT   133            750125              175000
# 131      Suriname  SUR   132            585824              131700
# 130  Sierra Leone  SIE   131           6018888             1402400
# 129    Mauritania  MAU   130           3677293             1523335
#
#      Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 132           104300                   4100                      7500
# 131            77100                   3030                      2270
# 130           835830                  32848                     10750
# 129          1061515                  72942                     20870
#
#      Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 132              7500                  0  ...                      0
# 131              2170                100  ...                      0
# 130             10750                  0  ...                      0
# 129             15870               5000  ...                    728
#
#      Serivecable Airports  Defense Budget  External Debt  \
# 132                     2              10           2261
# 131                    55              67           1439
# 130                     8              13           1561
# 129                    30              39        3585000
#
#      Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 132                       15                     6432                  38394
# 131                      393                     8547                 163820
# 130                     2332                    10640                  71740
# 129                     1186                    16710                1030700
#
#      Coastline (km)  Shared Borders (km)    Waterways (km)
# 132      Landlocked                 1136  Minimum not met.
# 131             386                 1907              1200
# 130             402                 1093               800
# 129             754                 5002  Minimum not met.
#
# [4 rows x 47 columns]

# %%
x=data.sort_values(by=["ISO3","Country"])

# %%
x.head(4)
# Out:
#         Country ISO3  Rank  Total Population  Manpower Available  \
# 68  Afghanistan  AFG    69          33332025            14000000
# 89      Albania  ALB    90           3038594             1515000
# 24      Algeria  ALG    25          40263711            20400000
# 50       Angola  ANG    51          20172332             6030000
#
#     Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 68          8000000                 765000                    200000
# 89          1300000                  62000                     64000
# 24         17250000                 675000                    792350
# 50          3040000                 310000                    175500
#
#     Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 68            200000                  0  ...                      0
# 89             50000              14000  ...                    339
# 24            520000             272350  ...                   3973
# 50            107000              68500  ...                   2764
#
#     Serivecable Airports  Defense Budget  External Debt  \
# 68                    43           11500           1280
# 89                     4             110           7797
# 24                   157           10570           5934
# 50                   176            4150          37700
#
#     Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 68                    66810                    64080                 652230
# 89                     3213                    34210                  28748
# 24                   115000                   609400                2381741
# 50                    20430                   187300                1246700
#
#     Coastline (km)  Shared Borders (km)    Waterways (km)
# 68      Landlocked                 5987              1200
# 89             362                  691                41
# 24             998                 6734  Minimum not met.
# 50            1600                 5369              1300
#
# [4 rows x 47 columns]

# %%
x=data.sort_values(by="Rank",ascending=False)

# %%
x.head(4)
# Out:
#           Country ISO3  Rank  Total Population  Manpower Available  \
# 132        Bhutan  BUT   133            750125              175000
# 131      Suriname  SUR   132            585824              131700
# 130  Sierra Leone  SIE   131           6018888             1402400
# 129    Mauritania  MAU   130           3677293             1523335
#
#      Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 132           104300                   4100                      7500
# 131            77100                   3030                      2270
# 130           835830                  32848                     10750
# 129          1061515                  72942                     20870
#
#      Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 132              7500                  0  ...                      0
# 131              2170                100  ...                      0
# 130             10750                  0  ...                      0
# 129             15870               5000  ...                    728
#
#      Serivecable Airports  Defense Budget  External Debt  \
# 132                     2              10           2261
# 131                    55              67           1439
# 130                     8              13           1561
# 129                    30              39        3585000
#
#      Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 132                       15                     6432                  38394
# 131                      393                     8547                 163820
# 130                     2332                    10640                  71740
# 129                     1186                    16710                1030700
#
#      Coastline (km)  Shared Borders (km)    Waterways (km)
# 132      Landlocked                 1136  Minimum not met.
# 131             386                 1907              1200
# 130             402                 1093               800
# 129             754                 5002  Minimum not met.
#
# [4 rows x 47 columns]

# %%
 x=data.sort_values(by=['Country','ISO3'])

# %%
x.head(4)
# Out:
#         Country ISO3  Rank  Total Population  Manpower Available  \
# 68  Afghanistan  AFG    69          33332025            14000000
# 89      Albania  ALB    90           3038594             1515000
# 24      Algeria  ALG    25          40263711            20400000
# 50       Angola  ANG    51          20172332             6030000
#
#     Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 68          8000000                 765000                    200000
# 89          1300000                  62000                     64000
# 24         17250000                 675000                    792350
# 50          3040000                 310000                    175500
#
#     Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 68            200000                  0  ...                      0
# 89             50000              14000  ...                    339
# 24            520000             272350  ...                   3973
# 50            107000              68500  ...                   2764
#
#     Serivecable Airports  Defense Budget  External Debt  \
# 68                    43           11500           1280
# 89                     4             110           7797
# 24                   157           10570           5934
# 50                   176            4150          37700
#
#     Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 68                    66810                    64080                 652230
# 89                     3213                    34210                  28748
# 24                   115000                   609400                2381741
# 50                    20430                   187300                1246700
#
#     Coastline (km)  Shared Borders (km)    Waterways (km)
# 68      Landlocked                 5987              1200
# 89             362                  691                41
# 24             998                 6734  Minimum not met.
# 50            1600                 5369              1300
#
# [4 rows x 47 columns]

# %%
x=data.rank(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 x=data.rank(axis=1)
#
# File C:\Python312\Lib\site-packages\pandas\core\generic.py:10101, in NDFrame.rank(self, axis, method, numeric_only, na_option, ascending, pct)
#   10098 else:
#   10099     data = self
# > 10101 return ranker(data)
#
# File C:\Python312\Lib\site-packages\pandas\core\generic.py:10078, in NDFrame.rank.<locals>.ranker(data)
#   10070     ranks = values._rank(
#   10071         axis=axis_int,
#   10072         method=method,
#    (...)
#   10075         pct=pct,
#   10076     )
#   10077 else:
# > 10078     ranks = algos.rank(
#   10079         values,
#   10080         axis=axis_int,
#   10081         method=method,
#   10082         ascending=ascending,
#   10083         na_option=na_option,
#   10084         pct=pct,
#   10085     )
#   10087 ranks_obj = self._constructor(ranks, **data._construct_axes_dict())
#   10088 return ranks_obj.__finalize__(self, method="rank")
#
# File C:\Python312\Lib\site-packages\pandas\core\algorithms.py:1111, in rank(values, axis, method, na_option, ascending, pct)
#    1102     ranks = algos.rank_1d(
#    1103         values,
#    1104         is_datetimelike=is_datetimelike,
#    (...)
#    1108         pct=pct,
#    1109     )
#    1110 elif values.ndim == 2:
# -> 1111     ranks = algos.rank_2d(
#    1112         values,
#    1113         axis=axis,
#    1114         is_datetimelike=is_datetimelike,
#    1115         ties_method=method,
#    1116         ascending=ascending,
#    1117         na_option=na_option,
#    1118         pct=pct,
#    1119     )
#    1120 else:
#    1121     raise TypeError("Array with ndim > 2 are not supported.")
#
# File algos.pyx:1331, in pandas._libs.algos.rank_2d()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
x.head(4)
# Out:
#    Country   ISO3  Rank  Total Population  Manpower Available  \
# 0    126.0  127.0   1.0             131.0               131.0
# 1     97.0   97.0   2.0             125.0               126.0
# 2     26.0   25.0   3.0             133.0               133.0
# 3     49.0   49.0   4.0             132.0               132.0
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 0            131.0                  129.0                     127.0
# 1            125.0                  117.0                     128.0
# 2            133.0                  132.0                     129.0
# 3            132.0                  133.0                     130.0
#
#    Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 0             132.0              123.0  ...                  133.0
# 1             129.0              129.0  ...                  132.0
# 2             133.0              126.0  ...                  131.0
# 3             131.0              130.0  ...                  130.0
#
#    Serivecable Airports  Defense Budget  External Debt  \
# 0                 133.0           133.0          133.0
# 1                 129.0           128.0          114.0
# 2                 121.0           132.0          120.0
# 3                 114.0           130.0          113.0
#
#    Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 0                    116.0                    132.0                  131.0
# 1                    127.0                    128.0                  133.0
# 2                    133.0                    133.0                  130.0
# 3                    126.0                    131.0                  127.0
#
#    Coastline (km)  Shared Borders (km)  Waterways (km)
# 0            25.0                128.0            67.0
# 1            62.0                132.0             5.0
# 2            10.0                133.0             9.0
# 3            91.0                130.0            20.0
#
# [4 rows x 47 columns]

# %%
x=data.iloc[0:8,0:8]

# %%
x.head(4)
# Out:
#          Country ISO3  Rank  Total Population  Manpower Available  \
# 0  United States  USA     1         323995528           145215000
# 1         Russia  RUS     2         142355415            70000000
# 2          China  CHN     3        1373541278           750000000
# 3          India  IND     4        1266883598           616000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel
# 0        120025000                4220000                   2363675
# 1         47000000                1355000                   3371027
# 2        619000000               19550000                   3712500
# 3        489600000               22900000                   4207250

# %%
x['mRank'] = x['Fit-for-Service'].rank(ascending=1)

# %%
x.head(6)
# Out:
#           Country ISO3  Rank  Total Population  Manpower Available  \
# 0   United States  USA     1         323995528           145215000
# 1          Russia  RUS     2         142355415            70000000
# 2           China  CHN     3        1373541278           750000000
# 3           India  IND     4        1266883598           616000000
# 4          France  FRA     5          66836154            30000000
# 5  United Kingdom  UKD     6          64430428            30000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  mRank
# 0        120025000                4220000                   2363675    6.0
# 1         47000000                1355000                   3371027    5.0
# 2        619000000               19550000                   3712500    8.0
# 3        489600000               22900000                   4207250    7.0
# 4         23750000                 775000                    387635    1.0
# 5         24040000                 750000                    232675    2.0
