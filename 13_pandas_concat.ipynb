# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame([['a',1],['b',2]],columns=['letter','number'])

# %%
df1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
df2 = pd.DataFrame([['c',3],['d',4]],columns=['letter','number'])

# %%
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
df3 = pd.DataFrame([['c',3,'cat'],['d',4,'dog']],columns=['letter','number','animal'])

# %%
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1,df2])
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
pd.concat([df1,df3],join="inner")
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
df3 = pd.DataFrame([['c',3,'cat'],['d',4,'dog']],columns=['letter','number','animal'])

# %%
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
pd.concat([df1,df3])
# Out:
#   letter  number animal
# 0      a       1    NaN
# 1      b       2    NaN
# 0      c       3    cat
# 1      d       4    dog

# %%
drink = pd.read_csv('starbucks-menu-nutrition-drinks.csv')

# %%
drink.head(5)
# Out:
#                                           Unnamed: 0 Calories Fat (g)  \
# 0           Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                   Ombré Pink Drink        -       -
# 2                                         Pink Drink        -       -
# 3     Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4  Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
#
#   Carb. (g) Fiber (g) Protein Sodium
# 0        11         0       0     10
# 1         -         -       -      -
# 2         -         -       -      -
# 3        18         1       0     10
# 4        14         1       0     10

# %%
drink = pd.read_csv('starbucks-menu-nutrition-drinks.csv')

# %%
drink.head(5)
# Out:
#                                           Unnamed: 0 Calories Fat (g)  \
# 0           Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                   Ombré Pink Drink        -       -
# 2                                         Pink Drink        -       -
# 3     Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4  Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
#
#   Carb. (g) Fiber (g) Protein Sodium
# 0        11         0       0     10
# 1         -         -       -      -
# 2         -         -       -      -
# 3        18         1       0     10
# 4        14         1       0     10

# %%
food=pd.read_csv("starbucks-food.csv",parse_dates=True,encoding='latin1')

# %%
food.head(5)
# Out:
#          Unnamed: 0   Calories   Fat (g)   Carb. (g)   Fiber (g)   Protein (g)
# 0      Chonga Bagel        300       5.0          50           3            12
# 1      8-Grain Roll        380       6.0          70           7            10
# 2  Almond Croissant        410      22.0          45           3            10
# 3     Apple Fritter        460      23.0          56           2             7
# 4  Banana Nut Bread        420      22.0          52           2             6

# %%
pd.concat([drink,food])
# Out:
#                                             Unnamed: 0 Calories Fat (g)  \
# 0             Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                     Ombré Pink Drink        -       -
# 2                                           Pink Drink        -       -
# 3       Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
# ..                                                 ...      ...     ...
# 108                 Justin's Chocolate Hazelnut Butter      NaN     NaN
# 109                     Justin's Classic Almond Butter      NaN     NaN
# 110                               Lemon Chiffon Yogurt      NaN     NaN
# 111                           Organic Avocado (Spread)      NaN     NaN
# 112                               Seasonal Fruit Blend      NaN     NaN
#
#     Carb. (g) Fiber (g) Protein Sodium   Calories   Fat (g)   Carb. (g)  \
# ...

# %%
pd.concat([drink,food])
# Out:
#                                             Unnamed: 0 Calories Fat (g)  \
# 0             Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                     Ombré Pink Drink        -       -
# 2                                           Pink Drink        -       -
# 3       Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
# ..                                                 ...      ...     ...
# 108                 Justin's Chocolate Hazelnut Butter      NaN     NaN
# 109                     Justin's Classic Almond Butter      NaN     NaN
# 110                               Lemon Chiffon Yogurt      NaN     NaN
# 111                           Organic Avocado (Spread)      NaN     NaN
# 112                               Seasonal Fruit Blend      NaN     NaN
#
#     Carb. (g) Fiber (g) Protein Sodium   Calories   Fat (g)   Carb. (g)  \
# ...
